# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# **Ler imagem**
#
# as cores vem invertidas, ao invez de RGB, o cv le BGR, NECESSITA TROCAR

# %%
img = cv2.imread("foz.jpg",cv2.IMREAD_COLOR )
plt.imshow(img)

# %%
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgRGB)

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(imgRGB)

# %%
help(cv2.imwrite)
